# %%
import import_ipynb
import os
import joblib
from keras.models import load_model
import pandas as pd
from train import code 

def train_and_save_models(data_directory):
    for file_name in os.listdir(data_directory):
        if file_name.endswith('.csv'):
            stock_name = os.path.splitext(file_name)[0]
            file_path = os.path.join(data_directory, file_name)
            print(f"Processing {stock_name}...")

            # Train the model
            model = code(file_path)

            # Save the trained model
            model_save_path = os.path.join(data_directory, f"{stock_name}_tft_model.keras")
            model.save(model_save_path)
            print(f"Model for {stock_name} saved at {model_save_path}")

            # Save the scaler
            scaler_save_path = os.path.join(data_directory, f"{stock_name}_scaler.pkl")
            scaler = joblib.load('scaler.pkl')
            joblib.dump(scaler, scaler_save_path)
            print(f"Scaler for {stock_name} saved at {scaler_save_path}")

if __name__ == "__main__":
    NULB_data_directory = '../csvfiles/NULB/'  # Change this to your actual directory path
    train_and_save_models(NULB_data_directory)
# Out:
# Trial 5 Complete [00h 00m 30s]
# val_loss: 0.16783592104911804
#
# Best val_loss So Far: 0.04801563918590546
# Total elapsed time: 00h 02m 38s
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x4cd5af140>
# Epoch 1/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - loss: 0.5548 - mean_absolute_error: 0.5548 - mean_squared_error: 0.5311 - val_loss: 0.2840 - val_mean_absolute_error: 0.2840 - val_mean_squared_error: 0.1128
# Epoch 2/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2276 - mean_absolute_error: 0.2276 - mean_squared_error: 0.0862 - val_loss: 0.0932 - val_mean_absolute_error: 0.0932 - val_mean_squared_error: 0.0125
# Epoch 3/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1534 - mean_absolute_error: 0.1534 - mean_squared_error: 0.0383 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - val_mean_squared_error: 0.0079
# Epoch 4/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1110 - mean_absolute_error: 0.1110 - mean_squared_error: 0.0209 - val_loss: 0.0433 - val_mean_absolute_error: 0.0433 - val_mean_squared_error: 0.0035
# Epoch 5/5
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - mean_squared_error: 0.0163 - val_loss: 0.0774 - val_mean_absolute_error: 0.0774 - val_mean_squared_error: 0.0077
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Nested Cross-Validation Scores:
# Fold 1:
#   Best Model - MSE: 0.006287559496878292, R^2: 0.8626898689312026, RMSE: 0.07929413280235992, MAE: 0.06230517878010084, Testing Time: 0.8695077896118164
#   Worst Model - MSE: 0.014527224283734775, R^2: 0.6827489153055644, RMSE: 0.12052893546254681, MAE: 0.08764879082310499
# Fold 2:
#   Best Model - MSE: 0.0038535976189995776, R^2: 0.912678302255095, RMSE: 0.06207735190066968, MAE: 0.04741006250260943, Testing Time: 0.716766357421875
#   Worst Model - MSE: 0.015116371962183408, R^2: 0.6574662447959438, RMSE: 0.12294865579656984, MAE: 0.09244531546893338
# Fold 3:
#   Best Model - MSE: 0.002792941697472191, R^2: 0.936403520697025, RMSE: 0.05284828944698391, MAE: 0.036759689287409525, Testing Time: 376.62766909599304
#   Worst Model - MSE: 0.014498499493061779, R^2: 0.6698629535413434, RMSE: 0.1204097151107907, MAE: 0.08869827516799852
# Fold 4:
#   Best Model - MSE: 0.002428928963956699, R^2: 0.9414040061724984, RMSE: 0.04928416544851601, MAE: 0.037930968660447574, Testing Time: 733.9018681049347
#   Worst Model - MSE: 0.012968991731743195, R^2: 0.6871333123615833, RMSE: 0.11388148107459437, MAE: 0.08543504436766772
# Fold 5:
#   Best Model - MSE: 0.002011006988988463, R^2: 0.9491992715057054, RMSE: 0.044844252574755473, MAE: 0.03603654424550117, Testing Time: 1120.4066531658173
#   Worst Model - MSE: 0.012760175234539744, R^2: 0.6776608926876311, RMSE: 0.11296094561634895, MAE: 0.08494407746807274
#
# Average Best Model Metrics across all folds:
# Average MSE: 0.003474806953259044
# Average MAE: 0.04408848869521371
# Average R^2: 0.9204749939123053
# Average RMSE: 0.057669638434657
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Optimizer: Adam
# Learning Rate: 0.0016176122007891536
# Dropout Rates:
# lstm_2: 0.0
# lstm_3: 0.0
# multi_head_attention_6: 0.344281141899901
# dropout_21: 0.344281141899901
# dropout_22: 0.344281141899901
# multi_head_attention_7: 0.4985257857260631
# dropout_24: 0.4985257857260631
# dropout_25: 0.4985257857260631
# dropout_26: 0.11014538897896561
# Best Hyperparameters: {'grn_units': 64, 'num_transformer_blocks': 2, 'head_size': 8, 'num_heads': 9, 'ff_dim': 12, 'dropout_0': 0.344281141899901, 'dropout_1': 0.4985257857260631, 'num_mlp_layers': 1, 'mlp_units_0': 32, 'mlp_dropout_0': 0.11014538897896561, 'optimizer': 'adam', 'learning_rate': 0.001617612182594877, 'dropout_2': 0.5789430538395982, 'dropout_3': 0.4504545337351199, 'dropout_4': 0.293366757218849, 'dropout_5': 0.5792929353016918, 'dropout_6': 0.511543868622865, 'dropout_7': 0.48032754752901907, 'mlp_units_1': 128, 'mlp_dropout_1': 0.1421339736877009, 'mlp_units_2': 32, 'mlp_dropout_2': 0.4379652413344064}
# Worst Hyperparameters: {'grn_units': 64, 'num_transformer_blocks': 4, 'head_size': 200, 'num_heads': 12, 'ff_dim': 49, 'dropout_0': 0.5459094170822424, 'dropout_1': 0.2454359560388891, 'num_mlp_layers': 2, 'mlp_units_0': 96, 'mlp_dropout_0': 0.16125947829019963, 'optimizer': 'adamax', 'learning_rate': 0.0014419497855851235, 'mlp_units_1': 64, 'mlp_dropout_1': 0.2017016242676901, 'dropout_2': 0.1, 'dropout_3': 0.1}
# Model for NULB saved at ../csvfiles/NULB/NULB_tft_model.keras
# Scaler for NULB saved at ../csvfiles/NULB/NULB_scaler.pkl
