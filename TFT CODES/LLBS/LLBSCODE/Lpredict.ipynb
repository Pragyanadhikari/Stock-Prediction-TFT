# %%
import import_ipynb
import os
import joblib
from keras.models import load_model
import pandas as pd
from train import code 

def train_and_save_models(data_directory):
    for file_name in os.listdir(data_directory):
        if file_name.endswith('.csv'):
            stock_name = os.path.splitext(file_name)[0]
            file_path = os.path.join(data_directory, file_name)
            print(f"Processing {stock_name}...")

            # Train the model
            model = code(file_path)

            # Save the trained model
            model_save_path = os.path.join(data_directory, f"{stock_name}_tft_model.keras")
            model.save(model_save_path)
            print(f"Model for {stock_name} saved at {model_save_path}")

            # Save the scaler
            scaler_save_path = os.path.join(data_directory, f"{stock_name}_scaler.pkl")
            scaler = joblib.load('scaler.pkl')
            joblib.dump(scaler, scaler_save_path)
            print(f"Scaler for {stock_name} saved at {scaler_save_path}")

if __name__ == "__main__":
    NULB_data_directory = '../csvfiles/llbs/'  # Change this to your actual directory path
    train_and_save_models(NULB_data_directory)
# Out:
# Trial 5 Complete [00h 01m 10s]
# val_loss: 0.13395188748836517
#
# Best val_loss So Far: 0.04301148280501366
# Total elapsed time: 00h 04m 29s
# Best hyperparameters for fold 1: <keras_tuner.src.engine.hyperparameters.hyperparameters.HyperParameters object at 0x4dfe24410>
# Epoch 1/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 15s 103ms/step - loss: 0.5002 - mean_absolute_error: 0.5002 - mean_squared_error: 0.4650 - val_loss: 0.1295 - val_mean_absolute_error: 0.1295 - val_mean_squared_error: 0.0321
# Epoch 2/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.2044 - mean_absolute_error: 0.2044 - mean_squared_error: 0.0676 - val_loss: 0.1159 - val_mean_absolute_error: 0.1159 - val_mean_squared_error: 0.0272
# Epoch 3/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.1591 - mean_absolute_error: 0.1591 - mean_squared_error: 0.0458 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - val_mean_squared_error: 0.0058
# Epoch 4/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 0.1027 - mean_absolute_error: 0.1027 - mean_squared_error: 0.0200 - val_loss: 0.0755 - val_mean_absolute_error: 0.0755 - val_mean_squared_error: 0.0087
# Epoch 5/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 0.0965 - mean_absolute_error: 0.0965 - mean_squared_error: 0.0179 - val_loss: 0.0734 - val_mean_absolute_error: 0.0734 - val_mean_squared_error: 0.0091
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# Nested Cross-Validation Scores:
# Fold 1:
#   Best Model - MSE: 0.0030845639185356068, R^2: 0.8997938605815547, RMSE: 0.055538850533078256, MAE: 0.042925935274651314, Testing Time: 178.75071573257446
#   Worst Model - MSE: 0.004629194164633952, R^2: 0.8496145036681275, RMSE: 0.06803818166760449, MAE: 0.05491058537618182
# Fold 2:
#   Best Model - MSE: 0.0031291680999554995, R^2: 0.9067166311873892, RMSE: 0.05593896763398033, MAE: 0.04114601616819407, Testing Time: 0.8201241493225098
#   Worst Model - MSE: 0.008280637887088545, R^2: 0.7531465957242935, RMSE: 0.09099801034686718, MAE: 0.06267452207923352
# Fold 3:
#   Best Model - MSE: 0.0027054704725722354, R^2: 0.9059483588673949, RMSE: 0.05201413723760335, MAE: 0.04049141076047797, Testing Time: 1.2014808654785156
#   Worst Model - MSE: 0.01134228128060008, R^2: 0.6057025277330643, RMSE: 0.10650014685717613, MAE: 0.07144680879495302
# Fold 4:
#   Best Model - MSE: 0.003082716963421882, R^2: 0.9154984152893644, RMSE: 0.05552222044750986, MAE: 0.042310256041953404, Testing Time: 567.4395878314972
#   Worst Model - MSE: 0.01354874724458147, R^2: 0.6286098832310123, RMSE: 0.11639908609856638, MAE: 0.07870386005154784
# Fold 5:
#   Best Model - MSE: 0.002543712761952636, R^2: 0.9113221018366585, RMSE: 0.05043523333893317, MAE: 0.03854793289924972, Testing Time: 297.44434690475464
#   Worst Model - MSE: 0.012484325106672784, R^2: 0.5647764452784587, RMSE: 0.11173327663088013, MAE: 0.07832212437227536
#
# Average Best Model Metrics across all folds:
# Average MSE: 0.0029091264432875717
# Average MAE: 0.041084310228905296
# Average R^2: 0.9078558735524723
# Average RMSE: 0.053889881838221
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Optimizer: Adamax
# Learning Rate: 0.0015078425640240312
# Dropout Rates:
# lstm_2: 0.0
# lstm_3: 0.0
# multi_head_attention_2: 0.3953728679562488
# dropout_10: 0.3953728679562488
# dropout_11: 0.3953728679562488
# multi_head_attention_3: 0.3150426707717152
# dropout_13: 0.3150426707717152
# dropout_14: 0.3150426707717152
# multi_head_attention_4: 0.46822201592333335
# dropout_16: 0.46822201592333335
# dropout_17: 0.46822201592333335
# multi_head_attention_5: 0.19475798035336214
# dropout_19: 0.19475798035336214
# dropout_20: 0.19475798035336214
# multi_head_attention_6: 0.22668671959796374
# dropout_22: 0.22668671959796374
# dropout_23: 0.22668671959796374
# multi_head_attention_7: 0.3740088047177327
# dropout_25: 0.3740088047177327
# dropout_26: 0.3740088047177327
# dropout_27: 0.16645446265700278
# dropout_28: 0.3813429788046203
# Best Hyperparameters: {'grn_units': 32, 'num_transformer_blocks': 6, 'head_size': 8, 'num_heads': 4, 'ff_dim': 8, 'dropout_0': 0.3953728679562488, 'dropout_1': 0.3150426707717152, 'num_mlp_layers': 2, 'mlp_units_0': 256, 'mlp_dropout_0': 0.16645446265700278, 'optimizer': 'adamax', 'learning_rate': 0.0015078425841316106, 'mlp_units_1': 160, 'mlp_dropout_1': 0.3813429788046203, 'dropout_2': 0.46822201592333335, 'dropout_3': 0.19475798035336214, 'dropout_4': 0.22668671959796374, 'dropout_5': 0.3740088047177327, 'dropout_6': 0.3861737800967069, 'dropout_7': 0.400245391661765}
# Worst Hyperparameters: {'grn_units': 64, 'num_transformer_blocks': 6, 'head_size': 104, 'num_heads': 5, 'ff_dim': 6, 'dropout_0': 0.14565716250294566, 'dropout_1': 0.29875008129979774, 'num_mlp_layers': 3, 'mlp_units_0': 64, 'mlp_dropout_0': 0.48645731528126634, 'optimizer': 'adamax', 'learning_rate': 0.0010199916044921445, 'dropout_2': 0.4786286872202703, 'dropout_3': 0.1541299092108039, 'dropout_4': 0.2521314912395596, 'dropout_5': 0.16825685629321166, 'mlp_units_1': 128, 'mlp_dropout_1': 0.3451559624893601, 'mlp_units_2': 160, 'mlp_dropout_2': 0.2859463952925607, 'dropout_6': 0.5922348083811125, 'dropout_7': 0.3260586191276086}
# Model for LLBS saved at ../csvfiles/llbs/LLBS_tft_model.keras
# Scaler for LLBS saved at ../csvfiles/llbs/LLBS_scaler.pkl
